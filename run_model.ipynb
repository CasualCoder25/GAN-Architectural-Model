# %%
import matplotlib.pyplot as plt
from tensorflow.config.experimental import list_physical_devices, set_memory_growth
from tensorflow.keras.preprocessing.image import load_img
from model import ImageGenModel
from postprocess import PostProcess

# %%
gpus=list_physical_devices('GPU')
for gpu in gpus:
    set_memory_growth(gpu,True)

# %%
model_path = r"C:\Users\Sagar\Python files_Jupiter\Git Repo Local\GAN Architectural Model\gan_results\g_models\g_model_052000.h5"
post_model_path = f"C:/Users/Sagar/Python files_Jupiter/Git Repo Local/GAN Architectural Model/post_gan_results/model_{10}.h5"

# %%
main_model = ImageGenModel(model_path)

# %%
post_model = PostProcess(post_model_path)

# %%
input_image = load_img(r"C:\Users\Sagar\Python files_Jupiter\Git Repo Local\GAN Architectural Model\processed_dataset\image_gan_in_final\71847.png")

# %%
plt.imshow(input_image)

# %%
gen_image = main_model.generate(input_image)

# %%
plt.imshow(gen_image[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
processed_image = post_model.process(input_image,gen_image)

# %%
plt.imshow(processed_image[0])

# %%
processed_image_advanced = post_model.process(input_image, gen_image, model_cycles=1, advanced=True, border_padding=2)

# %%
plt.imshow(processed_image_advanced[0])
